# %% [markdown]
# # Upselling and Cross Selling
#
# Upselling is the sales technique of encouraging customers to purchase a higher-end version or add premium features to their initial product selection, while cross-selling aims to sell complementary or related products to customers alongside their primary purchase. Association rule mining provides a powerful data-driven approach to identify these opportunities by uncovering hidden patterns and relationships between products in transaction data. By analyzing which items are frequently purchased together, businesses can generate personalized product recommendations that naturally align with customer preferences and purchase history. The insights derived from association rule mining enable more targeted marketing strategies, improved product bundling decisions, and strategic placement of complementary products, ultimately driving increased average order value, enhanced customer satisfaction, and higher revenue per customer interaction.
#
# We'll explore 2 methods of association rule mining:
# 1. Apriori
# 2. Eclat

# %% [markdown]
# ## Importing Libraries and Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori # pip install apyori
from pyECLAT import ECLAT # pip install pyECLAT

# %% [markdown]
# In our dataset, we're working with a grocery store owner who wants to increase her sales by offering BOGO deals. She doesn't know which items she should create BOGO deals with, and asked us to help. The store owner tracked every transaction at her point of sale for 7 days, and gave us a CSV where each row is a transaction, each row containing n items that were purchased in that transaction. We'll import this data and start exploring:

# %%
# The header=None argument tells read_csv that our input data doesn't have column labels. There are no features nor a second dimension to this dataset--just row upon row of transaction basket data
df = pd.read_csv('transaction_data.csv', header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %% [markdown]
# ## Apriori
#
# In its simplest form, Apriori is 'If this, then that.' Apriori algorithms look for sets of items that exist together, and create heuristics based on the frequency and consistency of those itemsets. Apriori relies on the idea that `If a set of items (itemset) is frequent, then all of its subsets must also be frequent. Conversely, if a set of items is infrequent, none of its supersets can be frequent.` A common use case is analyzing point of sale transactions to make deal recommendations, like in our scenario. We'll be using the `apriori` class from the `apyori` package. The `apriori` class expects a list of lists, where each sub-list is a transaction. Each item in the transaction list needs to be str, so we do some reformatting to pull the data out of the df and into an all-str list of lists.

# %% [markdown]
# ### Preprocessing

# %%
transactions = []
# For each row in the dataset, append the items to the transactions list
for i in range(len(df)):
  transactions.append([str(df.values[i,j]) for j in range(len(df.columns))])

print(transactions[0])
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']

# %% [markdown]
# ### Training/Mining

# %% [markdown]
# The `apriori` class expects 4 main arguments:
# 1. transactions: a list of transactions
# 2. min_support: support is the number of times a subset of items appears in the transaction list. The `apriori` class expects a minimum value to bound the list of output upsell rules to only include associations that are considered significant, expressed as a fraction of total transactions.
# 3. min_confidence: confidence refers to the strength of a given association rule, which describes the required % of applicable transactions where the rule applies. IE if min_confidence is 0.8, then the rule must apply to 80% of the transactions where the antecedent (requisite itemset) is present. This is a hyperparameter we can tune to end up with a higher or lower count of rules.
# 4. min_lift: lift measures the importance of the rule; how much more likely the second item is to be purchased when the first item is purchased. A lift value of 1 indicates that the items are unrelated (neither positive nor negative correlation). A lift value of more than 1 indicates that the second item is `lift_value` more times likely to be purchased when the first item is purchased. A lift value of less than 1 indicates that second item is (1/`lift_value`) times less likely to be purchased when the first item is purchased.

# %%
# Building a heuristic for min_support: let's consider itemsets that were bought at least 3 times a day. Our dataset is for 7 days total, so valid itemsets should occur at least 21 times. min_support is expressed as a percentage of transactions, so we divide 21 by the total transaction count and round.
min_support = round(3*7/len(transactions), 4)
min_confidence = 0.2
# min_length and max_length are the minimum and maximum number of items in the itemset. These values are heavily dependent on the business problem that underlies the apriori analysis. In our case, we want to recommend rules that correlate with BOGO deals, so we want to create rules that are only 2 items long: buy item A, get item B.
rules = apriori(transactions=transactions, min_support=min_support, min_confidence=min_confidence, min_lift=3, min_length=2, max_length=2)

# %% [markdown]
# ### Visualization

# %%
# Displaying the first results coming directly from the output of the apriori function
results = list(rules)
for rule in results[:10]:
    print(rule)
# Out:
# RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])
# RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)])
# RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)])
# RelationRecord(items=frozenset({'honey', 'fromage blanc'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'honey'}), confidence=0.2450980392156863, lift=5.164270764485569)])
# RelationRecord(items=frozenset({'herb & pepper', 'ground beef'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)])
# RelationRecord(items=frozenset({'tomato sauce', 'ground beef'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.3773584905660377, lift=3.840659481324083)])
# RelationRecord(items=frozenset({'olive oil', 'light cream'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'olive oil'}), confidence=0.20512820512820515, lift=3.1147098515519573)])
# RelationRecord(items=frozenset({'whole wheat pasta', 'olive oil'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.2714932126696833, lift=4.122410097642296)])
# RelationRecord(items=frozenset({'pasta', 'shrimp'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'shrimp'}), confidence=0.3220338983050847, lift=4.506672147735896)])

# %%
print("Number of rules: ",len(results))
# Out:
# Number of rules:  9

# %% [markdown]
# With our current parameters, we ended up with 9 association rules. Let's organize them into a df for easier analysis:

# %%
# This is a cool bit of code from stack overflow that helps visualize the rules. It extracts the left and right hand side products from the rule, as well as the support, confidence, and lift for each rule, then zips those together into a list of tuples. The final line (outside the inspect function) casts that list of tuples to a df.
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])
resultsinDataFrame
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 6           light cream       olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 8                 pasta          shrimp  0.005066    0.322034  4.506672

# %% [markdown]
# Let's sort by lift to get a better sense of which rules are most important:

# %%
resultsinDataFrame.sort_values(by='Lift', ascending=False).head()
# Out:
#       Left Hand Side Right Hand Side   Support  Confidence      Lift
# 3      fromage blanc           honey  0.003333    0.245098  5.164271
# 0        light cream         chicken  0.004533    0.290598  4.843951
# 2              pasta        escalope  0.005866    0.372881  4.700812
# 8              pasta          shrimp  0.005066    0.322034  4.506672
# 7  whole wheat pasta       olive oil  0.007999    0.271493  4.122410

# %% [markdown]
# The way we interpret these rules is that each rule constitutes a potential BOGO deal that our shop owner could offer. Buy `Left Hand Side` product, get `Right Hand Side` product for free. That's not to say that each rule is a great idea--giving a customer free chicken (expensive) when they buy light cream (cheap) may not be smart. These rules only indicate what products customers often purchase together, thus indicating items that could be paired together in deals, placed in close proximity in the store, or upsold the customer at the point of sale.
#
# Apriori is an established algorithm, but it has one critical flaw--it doesn't scale well. Apriori is memory intensive due to the fact that it needs multiple dataset scans to arrive at the set of rules. Apriori scans through the whole transaction list, then builds itemsets from that entire list. When working with larger or dense datasets, apriori is compute and memory heavy. Enter Eclat:

# %% [markdown]
# ## Eclat

# %% [markdown]
# Eclat is essentially a simplified form of Apriori. It leads to the same output of association rules, but does so in a more efficient way. While there is some nuance to that efficiency (intermediary Eclat transaction itemsets can consume a LOT of memory), Eclat is generally faster than Apriori.
#
# Apriori:
# 1. Scan transaction list data for 1-item sets
# 2. Build all possible itemsets by combining frequent sets from step 1
# 3. Scan data again to calculate support for each possible itemset
# 4. Remove itemsets that are infrequent
# 5. Repeat steps 2-4 until no more frequent itemsets are found
#
# Eclat:
# 1. Scan transaction list data to build a dictionary of `{item : [list of transaction IDs where item appears]}`
# 2. Build all possible itemsets by checking the length/size of the item's appearance list
# 3. Use set intersections to find larger frequent itemsets
# 4. Recursively extend itemsets in a depth-first manner
#
# In essence, where Apriori is a breadth-first search, Eclat is a depth-first search.

# %% [markdown]
# ### Training/Mining

# %%
eclat_model = ECLAT(data=df, verbose=True)
eclat_model.uniq_ # prints the unique items in the dataset
# Out:
# 100%|██████████| 120/120 [00:00<00:00, 180.06it/s]
# 100%|██████████| 120/120 [00:00<00:00, 5864.59it/s]
# 100%|██████████| 120/120 [00:00<00:00, 7501.33it/s]
# ['soup',
#  'sparkling water',
#  'gluten free bar',
#  'fromage blanc',
#  'red wine',
#  'dessert wine',
#  'shrimp',
#  'body spray',
#  'salmon',
#  'yogurt cake',
#  'cream',
#  'strong cheese',
#  'eggplant',
#  'mushroom cream sauce',
#  'burgers',
#  'rice',
#  'corn',
#  'hand protein bar',
#  'chili',
#  'tomatoes',
#  'chocolate',
#  'clothes accessories',
#  'champagne',
#  'asparagus',
#  'sandwich',
#  'muffins',
#  'shampoo',
#  'oil',
#  'cooking oil',
#  'chocolate bread',
#  'water spray',
#  'flax seed',
#  'mayonnaise',
#  'shallot',
#  'cookies',
#  'energy bar',
#  'tea',
#  'herb & pepper',
#  'brownies',
#  'chicken',
#  'mineral water',
#  'pasta',
#  'fresh tuna',
#  'hot dogs',
#  'white wine',
#  'oatmeal',
#  'pickles',
#  'zucchini',
#  'ham',
#  'whole weat flour',
#  'whole wheat pasta',
#  'mashed potato',
#  'fresh bread',
#  'green grapes',
#  'grated cheese',
#  ' asparagus',
#  'light mayo',
#  'barbecue sauce',
#  nan,
#  'soda',
#  'spinach',
#  'salad',
#  'pancakes',
#  'tomato sauce',
#  'eggs',
#  'cereals',
#  'french fries',
#  'pepper',
#  'bug spray',
#  'melons',
#  'cauliflower',
#  'extra dark chocolate',
#  'olive oil',
#  'mint',
#  'frozen vegetables',
#  'energy drink',
#  'green beans',
#  'yams',
#  'mint green tea',
#  'bacon',
#  'bramble',
#  'black tea',
#  'vegetables mix',
#  'magazines',
#  'almonds',
#  'french wine',
#  'blueberries',
#  'strawberries',
#  'carrots',
#  'whole wheat rice',
#  'low fat yogurt',
#  'protein bar',
#  'ketchup',
#  'gums',
#  'escalope',
#  'milk',
#  'salt',
#  'parmesan cheese',
#  'antioxydant juice',
#  'chutney',
#  'spaghetti',
#  'candy bars',
#  'nonfat milk',
#  'toothpaste',
#  'turkey',
#  'cottage cheese',
#  'napkins',
#  'burger sauce',
#  'meatballs',
#  'pet food',
#  'ground beef',
#  'honey',
#  'cider',
#  'avocado',
#  'cake',
#  'babies food',
#  'frozen smoothie',
#  'butter',
#  'tomato juice',
#  'light cream',
#  'green tea']

# %%
# fit the ECLAT model to the data
eclat_indexes, eclat_supports = eclat_model.fit(min_support=min_support, min_combination=2, max_combination=2, separator=' & ', verbose=True)
# Out:
# Combination 2 by 2
# 6555it [00:42, 154.26it/s]

# %%
eclat_supports
# Out:
# {'soup & shrimp': 0.005599253432875617,
#  'soup & salmon': 0.003199573390214638,
#  'soup & burgers': 0.006265831222503666,
#  'soup & tomatoes': 0.006932409012131715,
#  'soup & chocolate': 0.010131982402346354,
#  'soup & cooking oil': 0.005332622317024397,
#  'soup & herb & pepper': 0.0035995200639914677,
#  'soup & chicken': 0.005999200106652446,
#  'soup & mineral water': 0.023063591521130515,
#  'soup & grated cheese': 0.0029329422743634183,
#  'soup & pancakes': 0.006799093454206106,
#  'soup & eggs': 0.009065457938941474,
#  'soup & french fries': 0.007598986801759766,
#  'soup & olive oil': 0.008932142381015865,
#  'soup & frozen vegetables': 0.007998933475536596,
#  'soup & whole wheat rice': 0.0035995200639914677,
#  'soup & low fat yogurt': 0.005732568990801226,
#  'soup & escalope': 0.0034662045060658577,
#  'soup & milk': 0.015197973603519531,
#  'soup & spaghetti': 0.014264764698040262,
#  'soup & turkey': 0.004932675643247567,
#  'soup & ground beef': 0.009732035728569524,
#  'soup & honey': 0.003199573390214638,
#  'soup & avocado': 0.004399413411545127,
#  'soup & cake': 0.0061325156645780565,
#  'soup & green tea': 0.007065724570057326,
#  'fromage blanc & chocolate': 0.0030662578322890282,
#  'fromage blanc & mineral water': 0.004532728969470737,
#  'fromage blanc & eggs': 0.003999466737768298,
#  'fromage blanc & french fries': 0.0037328356219170776,
#  'fromage blanc & spaghetti': 0.0037328356219170776,
#  'fromage blanc & honey': 0.003332888948140248,
#  'red wine & burgers': 0.0037328356219170776,
#  'red wine & chocolate': 0.004932675643247567,
#  'red wine & mineral water': 0.010931875749900012,
#  'red wine & pancakes': 0.0034662045060658577,
#  'red wine & eggs': 0.007065724570057326,
#  'red wine & french fries': 0.005332622317024397,
#  'red wine & milk': 0.003999466737768298,
#  'red wine & spaghetti': 0.010265297960271964,
#  'red wine & turkey': 0.0029329422743634183,
#  'red wine & ground beef': 0.004799360085321957,
#  'red wine & cake': 0.003199573390214638,
#  'red wine & green tea': 0.004666044527396347,
#  'shrimp & salmon': 0.004666044527396347,
#  'shrimp & burgers': 0.008798826823090255,
#  'shrimp & tomatoes': 0.011198506865751233,
#  'shrimp & chocolate': 0.017997600319957337,
#  'shrimp & oil': 0.0034662045060658577,
#  'shrimp & cooking oil': 0.005999200106652446,
#  'shrimp & cookies': 0.0041327822956939075,
#  'shrimp & herb & pepper': 0.007065724570057326,
#  'shrimp & brownies': 0.003199573390214638,
#  'shrimp & chicken': 0.006265831222503666,
#  'shrimp & mineral water': 0.023596853752832957,
#  'shrimp & pasta': 0.005065991201173177,
#  'shrimp & whole wheat pasta': 0.0034662045060658577,
#  'shrimp & fresh bread': 0.005199306759098787,
#  'shrimp & grated cheese': 0.004399413411545127,
#  'shrimp & pancakes': 0.010531929076123183,
#  'shrimp & eggs': 0.014131449140114652,
#  'shrimp & cereals': 0.003199573390214638,
#  'shrimp & french fries': 0.009998666844420743,
#  'shrimp & pepper': 0.0034662045060658577,
#  'shrimp & olive oil': 0.008132249033462205,
#  'shrimp & frozen vegetables': 0.01666444474070124,
#  'shrimp & whole wheat rice': 0.005865884548726837,
#  'shrimp & low fat yogurt': 0.006265831222503666,
#  'shrimp & escalope': 0.004266097853619517,
#  'shrimp & milk': 0.01759765364618051,
#  'shrimp & parmesan cheese': 0.003332888948140248,
#  'shrimp & spaghetti': 0.021197173710171976,
#  'shrimp & turkey': 0.006399146780429276,
#  'shrimp & ground beef': 0.011465137981602452,
#  'shrimp & honey': 0.004399413411545127,
#  'shrimp & avocado': 0.0030662578322890282,
#  'shrimp & cake': 0.007598986801759766,
#  'shrimp & frozen smoothie': 0.007332355685908546,
#  'shrimp & butter': 0.0037328356219170776,
#  'shrimp & tomato juice': 0.0035995200639914677,
#  'shrimp & green tea': 0.011465137981602452,
#  'body spray & mineral water': 0.0041327822956939075,
#  'body spray & french fries': 0.004266097853619517,
#  'salmon & burgers': 0.004532728969470737,
#  'salmon & tomatoes': 0.004932675643247567,
#  'salmon & chocolate': 0.010665244634048793,
#  'salmon & cooking oil': 0.0038661511798426876,
#  'salmon & herb & pepper': 0.0038661511798426876,
#  'salmon & chicken': 0.003999466737768298,
#  'salmon & mineral water': 0.017064391414478068,
#  'salmon & grated cheese': 0.005199306759098787,
#  'salmon & pancakes': 0.004266097853619517,
#  'salmon & eggs': 0.008265564591387815,
#  'salmon & french fries': 0.005865884548726837,
#  'salmon & olive oil': 0.005732568990801226,
#  'salmon & frozen vegetables': 0.006265831222503666,
#  'salmon & low fat yogurt': 0.0038661511798426876,
#  'salmon & escalope': 0.003332888948140248,
#  'salmon & milk': 0.009732035728569524,
#  'salmon & spaghetti': 0.013464871350486601,
#  'salmon & turkey': 0.0041327822956939075,
#  'salmon & ground beef': 0.008932142381015865,
#  'salmon & honey': 0.0034662045060658577,
#  'salmon & cake': 0.0037328356219170776,
#  'salmon & frozen smoothie': 0.005065991201173177,
#  'salmon & green tea': 0.005865884548726837,
#  'yogurt cake & chocolate': 0.004399413411545127,
#  'yogurt cake & mineral water': 0.005599253432875617,
#  'yogurt cake & pancakes': 0.0035995200639914677,
#  'yogurt cake & eggs': 0.004532728969470737,
#  'yogurt cake & french fries': 0.005065991201173177,
#  'yogurt cake & milk': 0.003199573390214638,
#  'yogurt cake & spaghetti': 0.0038661511798426876,
#  'yogurt cake & green tea': 0.0038661511798426876,
#  'strong cheese & mineral water': 0.003199573390214638,
#  'strong cheese & spaghetti': 0.0037328356219170776,
#  'eggplant & mineral water': 0.0037328356219170776,
#  'eggplant & eggs': 0.0035995200639914677,
#  'eggplant & spaghetti': 0.0038661511798426876,
#  'mushroom cream sauce & chocolate': 0.004399413411545127,
#  'mushroom cream sauce & mineral water': 0.0029329422743634183,
#  'mushroom cream sauce & eggs': 0.0034662045060658577,
#  'mushroom cream sauce & french fries': 0.004666044527396347,
#  'mushroom cream sauce & escalope': 0.005732568990801226,
#  'mushroom cream sauce & spaghetti': 0.004266097853619517,
#  'mushroom cream sauce & green tea': 0.0035995200639914677,
#  'burgers & tomatoes': 0.008265564591387815,
#  'burgers & chocolate': 0.017064391414478068,
#  'burgers & champagne': 0.0038661511798426876,
#  'burgers & cooking oil': 0.005732568990801226,
#  'burgers & cookies': 0.005599253432875617,
#  'burgers & herb & pepper': 0.0041327822956939075,
#  'burgers & brownies': 0.003332888948140248,
#  'burgers & chicken': 0.006265831222503666,
#  'burgers & mineral water': 0.024396747100386616,
#  'burgers & fresh tuna': 0.0035995200639914677,
#  'burgers & hot dogs': 0.0038661511798426876,
#  'burgers & ham': 0.005599253432875617,
#  'burgers & whole wheat pasta': 0.0037328356219170776,
#  'burgers & fresh bread': 0.003999466737768298,
#  'burgers & grated cheese': 0.005465937874950006,
#  'burgers & light mayo': 0.003332888948140248,
#  'burgers & pancakes': 0.010531929076123183,
#  'burgers & eggs': 0.02879616051193174,
#  'burgers & cereals': 0.0034662045060658577,
#  'burgers & french fries': 0.021997067057725635,
#  'burgers & olive oil': 0.006399146780429276,
#  'burgers & frozen vegetables': 0.010531929076123183,
#  'burgers & almonds': 0.005199306759098787,
#  'burgers & french wine': 0.0041327822956939075,
#  'burgers & whole wheat rice': 0.008932142381015865,
#  'burgers & low fat yogurt': 0.006665777896280496,
#  'burgers & escalope': 0.007065724570057326,
#  'burgers & milk': 0.01786428476203173,
#  'burgers & spaghetti': 0.021463804826023197,
#  'burgers & turkey': 0.010665244634048793,
#  'burgers & cottage cheese': 0.003332888948140248,
#  'burgers & ground beef': 0.011998400213304892,
#  'burgers & honey': 0.006265831222503666,
#  'burgers & avocado': 0.004532728969470737,
#  'burgers & cake': 0.011465137981602452,
#  'burgers & frozen smoothie': 0.007199040127982935,
#  'burgers & butter': 0.0030662578322890282,
#  'burgers & tomato juice': 0.003332888948140248,
#  'burgers & green tea': 0.0174643380882549,
#  'rice & chocolate': 0.005332622317024397,
#  'rice & herb & pepper': 0.0029329422743634183,
#  'rice & mineral water': 0.007732302359685375,
#  'rice & eggs': 0.0030662578322890282,
#  'rice & french fries': 0.004799360085321957,
#  'rice & spaghetti': 0.005065991201173177,
#  'rice & ground beef': 0.004399413411545127,
#  'rice & green tea': 0.003332888948140248,
#  'tomatoes & chocolate': 0.013998133582189041,
#  'tomatoes & cooking oil': 0.006665777896280496,
#  'tomatoes & cookies': 0.0029329422743634183,
#  'tomatoes & herb & pepper': 0.004399413411545127,
#  'tomatoes & brownies': 0.0029329422743634183,
#  'tomatoes & chicken': 0.006399146780429276,
#  'tomatoes & mineral water': 0.024396747100386616,
#  'tomatoes & fresh bread': 0.004666044527396347,
#  'tomatoes & grated cheese': 0.004399413411545127,
#  'tomatoes & pancakes': 0.009865351286495135,
#  'tomatoes & eggs': 0.012265031329156113,
#  'tomatoes & french fries': 0.011998400213304892,
#  'tomatoes & olive oil': 0.007199040127982935,
#  'tomatoes & frozen vegetables': 0.0161311825089988,
#  'tomatoes & vegetables mix': 0.003199573390214638,
#  'tomatoes & whole wheat rice': 0.005999200106652446,
#  'tomatoes & low fat yogurt': 0.005999200106652446,
#  'tomatoes & escalope': 0.005465937874950006,
#  'tomatoes & milk': 0.013998133582189041,
#  'tomatoes & parmesan cheese': 0.003199573390214638,
#  'tomatoes & spaghetti': 0.020930542594320756,
#  'tomatoes & turkey': 0.006532462338354886,
#  'tomatoes & meatballs': 0.0038661511798426876,
#  'tomatoes & ground beef': 0.011731769097453673,
#  'tomatoes & honey': 0.005332622317024397,
#  'tomatoes & avocado': 0.0034662045060658577,
#  'tomatoes & cake': 0.008398880149313425,
#  'tomatoes & frozen smoothie': 0.006532462338354886,
#  'tomatoes & butter': 0.0030662578322890282,
#  'tomatoes & tomato juice': 0.0035995200639914677,
#  'tomatoes & green tea': 0.012265031329156113,
#  'chocolate & champagne': 0.011598453539528063,
#  'chocolate & muffins': 0.003999466737768298,
#  'chocolate & oil': 0.0061325156645780565,
#  'chocolate & cooking oil': 0.013598186908412212,
#  'chocolate & cookies': 0.010398613518197574,
#  'chocolate & energy bar': 0.003999466737768298,
#  'chocolate & herb & pepper': 0.009065457938941474,
#  'chocolate & brownies': 0.004932675643247567,
#  'chocolate & chicken': 0.014664711371817091,
#  'chocolate & mineral water': 0.05265964538061592,
#  'chocolate & fresh tuna': 0.004799360085321957,
#  'chocolate & hot dogs': 0.005465937874950006,
#  'chocolate & white wine': 0.0034662045060658577,
#  'chocolate & ham': 0.006265831222503666,
#  'chocolate & whole wheat pasta': 0.006265831222503666,
#  'chocolate & fresh bread': 0.009465404612718305,
#  'chocolate & grated cheese': 0.010931875749900012,
#  'chocolate & light mayo': 0.005065991201173177,
#  'chocolate & pancakes': 0.01986401813091588,
#  'chocolate & tomato sauce': 0.005065991201173177,
#  'chocolate & eggs': 0.03319557392347687,
#  'chocolate & cereals': 0.005599253432875617,
#  'chocolate & french fries': 0.03439541394480736,
#  'chocolate & pepper': 0.006399146780429276,
#  'chocolate & olive oil': 0.01639781362485002,
#  'chocolate & mint': 0.003332888948140248,
#  'chocolate & frozen vegetables': 0.022930275963204905,
#  'chocolate & energy drink': 0.0034662045060658577,
#  'chocolate & vegetables mix': 0.004799360085321957,
#  'chocolate & almonds': 0.005999200106652446,
#  'chocolate & french wine': 0.005199306759098787,
#  'chocolate & strawberries': 0.0034662045060658577,
#  'chocolate & carrots': 0.0034662045060658577,
#  'chocolate & whole wheat rice': 0.011998400213304892,
#  'chocolate & low fat yogurt': 0.014798026929742702,
#  'chocolate & protein bar': 0.0030662578322890282,
#  'chocolate & escalope': 0.01759765364618051,
#  'chocolate & milk': 0.03212904946007199,
#  'chocolate & parmesan cheese': 0.004266097853619517,
#  'chocolate & spaghetti': 0.03919477403012932,
#  'chocolate & turkey': 0.011331822423676844,
#  'chocolate & cottage cheese': 0.004932675643247567,
#  'chocolate & ground beef': 0.023063591521130515,
#  'chocolate & honey': 0.007998933475536596,
#  'chocolate & avocado': 0.007065724570057326,
#  'chocolate & cake': 0.013598186908412212,
#  'chocolate & frozen smoothie': 0.01493134248766831,
#  'chocolate & butter': 0.008265564591387815,
#  'chocolate & tomato juice': 0.005865884548726837,
#  'chocolate & light cream': 0.0035995200639914677,
#  'chocolate & green tea': 0.023463538194907346,
#  'champagne & cookies': 0.0037328356219170776,
#  'champagne & mineral water': 0.007465671243834155,
#  'champagne & pancakes': 0.005065991201173177,
#  'champagne & eggs': 0.006665777896280496,
#  'champagne & french fries': 0.009332089054792695,
#  'champagne & frozen vegetables': 0.004799360085321957,
#  'champagne & whole wheat rice': 0.0030662578322890282,
#  'champagne & low fat yogurt': 0.003199573390214638,
#  'champagne & escalope': 0.003999466737768298,
#  'champagne & milk': 0.005332622317024397,
#  'champagne & spaghetti': 0.006665777896280496,
#  'champagne & ground beef': 0.003999466737768298,
#  'champagne & frozen smoothie': 0.004666044527396347,
#  'champagne & green tea': 0.008265564591387815,
#  'muffins & mineral water': 0.004399413411545127,
#  'muffins & eggs': 0.0034662045060658577,
#  'muffins & french fries': 0.005332622317024397,
#  'muffins & frozen vegetables': 0.0035995200639914677,
#  'muffins & milk': 0.0030662578322890282,
#  'muffins & spaghetti': 0.0035995200639914677,
#  'oil & mineral water': 0.007332355685908546,
#  'oil & pancakes': 0.0037328356219170776,
#  'oil & eggs': 0.0034662045060658577,
#  'oil & french fries': 0.003999466737768298,
#  'oil & milk': 0.0041327822956939075,
#  'oil & spaghetti': 0.005732568990801226,
#  'oil & ground beef': 0.0038661511798426876,
#  'oil & green tea': 0.0041327822956939075,
#  'cooking oil & herb & pepper': 0.005332622317024397,
#  'cooking oil & brownies': 0.0029329422743634183,
#  'cooking oil & chicken': 0.006799093454206106,
#  'cooking oil & mineral water': 0.020130649246767097,
#  'cooking oil & fresh bread': 0.0029329422743634183,
#  'cooking oil & grated cheese': 0.005732568990801226,
#  'cooking oil & pancakes': 0.007865617917610986,
#  'cooking oil & eggs': 0.011731769097453673,
#  'cooking oil & cereals': 0.0029329422743634183,
#  'cooking oil & french fries': 0.007865617917610986,
#  'cooking oil & olive oil': 0.005065991201173177,
#  'cooking oil & frozen vegetables': 0.006799093454206106,
#  'cooking oil & whole wheat rice': 0.005465937874950006,
#  'cooking oil & low fat yogurt': 0.006532462338354886,
#  'cooking oil & escalope': 0.005332622317024397,
#  'cooking oil & milk': 0.011465137981602452,
#  'cooking oil & spaghetti': 0.01586455139314758,
#  'cooking oil & turkey': 0.005732568990801226,
#  'cooking oil & ground beef': 0.008398880149313425,
#  'cooking oil & honey': 0.003332888948140248,
#  'cooking oil & cake': 0.004932675643247567,
#  'cooking oil & frozen smoothie': 0.004799360085321957,
#  'cooking oil & butter': 0.0030662578322890282,
#  'cooking oil & tomato juice': 0.0029329422743634183,
#  'cooking oil & green tea': 0.007065724570057326,
#  'flax seed & green tea': 0.0030662578322890282,
#  'mayonnaise & mineral water': 0.0029329422743634183,
#  'cookies & mineral water': 0.007465671243834155,
#  'cookies & pancakes': 0.005199306759098787,
#  'cookies & eggs': 0.010531929076123183,
#  'cookies & french fries': 0.013331555792560993,
#  'cookies & whole wheat rice': 0.003999466737768298,
#  'cookies & low fat yogurt': 0.005332622317024397,
#  'cookies & milk': 0.004399413411545127,
#  'cookies & spaghetti': 0.007998933475536596,
#  'cookies & ground beef': 0.004399413411545127,
#  'cookies & cake': 0.003999466737768298,
#  'cookies & frozen smoothie': 0.0030662578322890282,
#  'cookies & green tea': 0.011998400213304892,
#  'energy bar & mineral water': 0.006799093454206106,
#  'energy bar & eggs': 0.005199306759098787,
#  'energy bar & french fries': 0.004799360085321957,
#  'energy bar & frozen vegetables': 0.0041327822956939075,
#  'energy bar & milk': 0.005465937874950006,
#  'energy bar & spaghetti': 0.004399413411545127,
#  'energy bar & cake': 0.003199573390214638,
#  'energy bar & green tea': 0.0030662578322890282,
#  'herb & pepper & chicken': 0.004932675643247567,
#  'herb & pepper & mineral water': 0.017064391414478068,
#  'herb & pepper & whole wheat pasta': 0.0037328356219170776,
#  'herb & pepper & fresh bread': 0.0030662578322890282,
#  'herb & pepper & grated cheese': 0.006532462338354886,
#  'herb & pepper & pancakes': 0.007332355685908546,
#  'herb & pepper & eggs': 0.012531662445007332,
#  'herb & pepper & cereals': 0.003199573390214638,
#  'herb & pepper & french fries': 0.006932409012131715,
#  'herb & pepper & olive oil': 0.005065991201173177,
#  'herb & pepper & frozen vegetables': 0.005999200106652446,
#  'herb & pepper & whole wheat rice': 0.003332888948140248,
#  'herb & pepper & low fat yogurt': 0.005865884548726837,
#  'herb & pepper & escalope': 0.0035995200639914677,
#  'herb & pepper & milk': 0.009198773496867084,
#  'herb & pepper & spaghetti': 0.01626449806692441,
#  'herb & pepper & turkey': 0.004799360085321957,
#  'herb & pepper & ground beef': 0.015997866951073192,
#  'herb & pepper & honey': 0.003199573390214638,
#  'herb & pepper & cake': 0.004532728969470737,
#  'herb & pepper & frozen smoothie': 0.0037328356219170776,
#  'herb & pepper & green tea': 0.006399146780429276,
#  'brownies & mineral water': 0.009598720170643914,
#  'brownies & pancakes': 0.005465937874950006,
#  'brownies & eggs': 0.007332355685908546,
#  'brownies & french fries': 0.007865617917610986,
#  'brownies & olive oil': 0.0037328356219170776,
#  'brownies & frozen vegetables': 0.004399413411545127,
#  'brownies & low fat yogurt': 0.003199573390214638,
#  'brownies & milk': 0.005465937874950006,
#  'brownies & spaghetti': 0.007332355685908546,
#  'brownies & cottage cheese': 0.0034662045060658577,
#  'brownies & ground beef': 0.004932675643247567,
#  'brownies & cake': 0.005465937874950006,
#  'brownies & green tea': 0.006665777896280496,
#  'chicken & mineral water': 0.022796960405279298,
#  'chicken & hot dogs': 0.0030662578322890282,
#  'chicken & whole wheat pasta': 0.003332888948140248,
#  'chicken & fresh bread': 0.005199306759098787,
#  'chicken & grated cheese': 0.004266097853619517,
#  'chicken & pancakes': 0.009065457938941474,
#  'chicken & eggs': 0.01439808025596587,
#  'chicken & french fries': 0.011065191307825623,
#  'chicken & olive oil': 0.007199040127982935,
#  'chicken & frozen vegetables': 0.008932142381015865,
#  'chicken & whole wheat rice': 0.005465937874950006,
#  'chicken & low fat yogurt': 0.004399413411545127,
#  'chicken & escalope': 0.0035995200639914677,
#  'chicken & milk': 0.014798026929742702,
#  'chicken & spaghetti': 0.01719770697240368,
#  'chicken & turkey': 0.004799360085321957,
#  'chicken & cottage cheese': 0.003199573390214638,
#  'chicken & meatballs': 0.003199573390214638,
#  'chicken & ground beef': 0.009465404612718305,
#  'chicken & honey': 0.0041327822956939075,
#  'chicken & cake': 0.006532462338354886,
#  'chicken & frozen smoothie': 0.006665777896280496,
#  'chicken & butter': 0.004266097853619517,
#  'chicken & tomato juice': 0.003332888948140248,
#  'chicken & light cream': 0.004532728969470737,
#  'chicken & green tea': 0.011865084655379284,
#  'mineral water & fresh tuna': 0.008798826823090255,
#  'mineral water & hot dogs': 0.009198773496867084,
#  'mineral water & white wine': 0.004399413411545127,
#  'mineral water & zucchini': 0.0034662045060658577,
#  'mineral water & ham': 0.009198773496867084,
#  'mineral water & whole weat flour': 0.0034662045060658577,
#  'mineral water & whole wheat pasta': 0.009598720170643914,
#  'mineral water & fresh bread': 0.013331555792560993,
#  'mineral water & green grapes': 0.003199573390214638,
#  'mineral water & grated cheese': 0.0174643380882549,
#  'mineral water & light mayo': 0.006265831222503666,
#  'mineral water & barbecue sauce': 0.0038661511798426876,
#  'mineral water & pancakes': 0.03372883615517931,
#  'mineral water & tomato sauce': 0.005732568990801226,
#  'mineral water & eggs': 0.05092654312758299,
#  'mineral water & cereals': 0.010265297960271964,
#  'mineral water & french fries': 0.03372883615517931,
#  'mineral water & pepper': 0.008265564591387815,
#  'mineral water & extra dark chocolate': 0.005732568990801226,
#  'mineral water & olive oil': 0.027596320490601255,
#  'mineral water & mint': 0.005865884548726837,
#  'mineral water & frozen vegetables': 0.03572856952406346,
#  'mineral water & energy drink': 0.005599253432875617,
#  'mineral water & yams': 0.0035995200639914677,
#  'mineral water & bacon': 0.0030662578322890282,
#  'mineral water & black tea': 0.005332622317024397,
#  'mineral water & vegetables mix': 0.007865617917610986,
#  'mineral water & magazines': 0.0037328356219170776,
#  'mineral water & almonds': 0.007598986801759766,
#  'mineral water & french wine': 0.008265564591387815,
#  'mineral water & blueberries': 0.0035995200639914677,
#  'mineral water & strawberries': 0.005065991201173177,
#  'mineral water & carrots': 0.005332622317024397,
#  'mineral water & whole wheat rice': 0.020130649246767097,
#  'mineral water & low fat yogurt': 0.023996800426609784,
#  'mineral water & protein bar': 0.007732302359685375,
#  'mineral water & gums': 0.004932675643247567,
#  'mineral water & escalope': 0.017064391414478068,
#  'mineral water & milk': 0.04799360085321957,
#  'mineral water & parmesan cheese': 0.004666044527396347,
#  'mineral water & spaghetti': 0.05972536995067324,
#  'mineral water & nonfat milk': 0.005065991201173177,
#  'mineral water & turkey': 0.019197440341287828,
#  'mineral water & cottage cheese': 0.009598720170643914,
#  'mineral water & meatballs': 0.007732302359685375,
#  'mineral water & ground beef': 0.040927876283162246,
#  'mineral water & honey': 0.015064658045593921,
#  'mineral water & avocado': 0.011598453539528063,
#  'mineral water & cake': 0.027463004932675644,
#  'mineral water & frozen smoothie': 0.020263964804692707,
#  'mineral water & butter': 0.0030662578322890282,
#  'mineral water & tomato juice': 0.009598720170643914,
#  'mineral water & light cream': 0.007332355685908546,
#  'mineral water & green tea': 0.03106252499666711,
#  'pasta & french fries': 0.0030662578322890282,
#  'pasta & escalope': 0.005865884548726837,
#  'fresh tuna & pancakes': 0.005065991201173177,
#  'fresh tuna & eggs': 0.005865884548726837,
#  'fresh tuna & french fries': 0.0038661511798426876,
#  'fresh tuna & olive oil': 0.0037328356219170776,
#  'fresh tuna & frozen vegetables': 0.0041327822956939075,
#  'fresh tuna & milk': 0.004799360085321957,
#  'fresh tuna & spaghetti': 0.006799093454206106,
#  'fresh tuna & honey': 0.003999466737768298,
#  'fresh tuna & cake': 0.0037328356219170776,
#  'fresh tuna & frozen smoothie': 0.0029329422743634183,
#  'fresh tuna & green tea': 0.003199573390214638,
#  'hot dogs & fresh bread': 0.0029329422743634183,
#  'hot dogs & pancakes': 0.004266097853619517,
#  'hot dogs & eggs': 0.0035995200639914677,
#  'hot dogs & french fries': 0.007332355685908546,
#  'hot dogs & olive oil': 0.0030662578322890282,
#  'hot dogs & frozen vegetables': 0.003999466737768298,
#  'hot dogs & milk': 0.004399413411545127,
#  'hot dogs & spaghetti': 0.008665511265164644,
#  'hot dogs & ground beef': 0.0038661511798426876,
#  'hot dogs & cake': 0.0035995200639914677,
#  'hot dogs & frozen smoothie': 0.004799360085321957,
#  'hot dogs & green tea': 0.006665777896280496,
#  'white wine & milk': 0.0034662045060658577,
#  'white wine & spaghetti': 0.004532728969470737,
#  'zucchini & spaghetti': 0.0030662578322890282,
#  'ham & pancakes': 0.004532728969470737,
#  'ham & eggs': 0.006265831222503666,
#  'ham & french fries': 0.005599253432875617,
#  'ham & olive oil': 0.0035995200639914677,
#  'ham & frozen vegetables': 0.0029329422743634183,
#  'ham & whole wheat rice': 0.004266097853619517,
#  'ham & low fat yogurt': 0.0029329422743634183,
#  'ham & milk': 0.004932675643247567,
#  'ham & spaghetti': 0.009198773496867084,
#  'ham & turkey': 0.0030662578322890282,
#  'ham & ground beef': 0.004932675643247567,
#  'ham & green tea': 0.004932675643247567,
#  'whole wheat pasta & pancakes': 0.004666044527396347,
#  'whole wheat pasta & eggs': 0.004932675643247567,
#  'whole wheat pasta & french fries': 0.005465937874950006,
#  'whole wheat pasta & olive oil': 0.007998933475536596,
#  'whole wheat pasta & frozen vegetables': 0.004932675643247567,
#  'whole wheat pasta & milk': 0.009865351286495135,
#  'whole wheat pasta & spaghetti': 0.008798826823090255,
#  'whole wheat pasta & ground beef': 0.004532728969470737,
#  'whole wheat pasta & cake': 0.0035995200639914677,
#  'whole wheat pasta & green tea': 0.005199306759098787,
#  'fresh bread & grated cheese': 0.0030662578322890282,
#  'fresh bread & pancakes': 0.005332622317024397,
#  'fresh bread & eggs': 0.008665511265164644,
#  'fresh bread & french fries': 0.008265564591387815,
#  'fresh bread & olive oil': 0.005065991201173177,
#  'fresh bread & frozen vegetables': 0.006799093454206106,
#  'fresh bread & whole wheat rice': 0.0037328356219170776,
#  'fresh bread & low fat yogurt': 0.004266097853619517,
#  'fresh bread & escalope': 0.0035995200639914677,
#  'fresh bread & milk': 0.009198773496867084,
#  'fresh bread & spaghetti': 0.009065457938941474,
#  'fresh bread & turkey': 0.003199573390214638,
#  'fresh bread & ground beef': 0.0061325156645780565,
#  'fresh bread & cake': 0.004399413411545127,
#  'fresh bread & frozen smoothie': 0.004266097853619517,
#  'fresh bread & tomato juice': 0.004266097853619517,
#  'fresh bread & green tea': 0.006399146780429276,
#  'grated cheese & pancakes': 0.006932409012131715,
#  'grated cheese & eggs': 0.009065457938941474,
#  'grated cheese & french fries': 0.010398613518197574,
#  'grated cheese & olive oil': 0.006265831222503666,
#  'grated cheese & frozen vegetables': 0.006799093454206106,
#  'grated cheese & whole wheat rice': 0.004532728969470737,
#  'grated cheese & low fat yogurt': 0.005599253432875617,
#  'grated cheese & escalope': 0.004799360085321957,
#  'grated cheese & milk': 0.007865617917610986,
#  'grated cheese & spaghetti': 0.01653112918277563,
#  'grated cheese & turkey': 0.004932675643247567,
#  'grated cheese & ground beef': 0.011331822423676844,
#  'grated cheese & honey': 0.0041327822956939075,
#  'grated cheese & cake': 0.004799360085321957,
#  'grated cheese & frozen smoothie': 0.003199573390214638,
#  'grated cheese & butter': 0.0030662578322890282,
#  'grated cheese & green tea': 0.007865617917610986,
#  'light mayo & pancakes': 0.005465937874950006,
#  'light mayo & eggs': 0.005465937874950006,
#  'light mayo & french fries': 0.007332355685908546,
#  'light mayo & frozen vegetables': 0.004399413411545127,
#  'light mayo & milk': 0.0034662045060658577,
#  'light mayo & spaghetti': 0.0038661511798426876,
#  'light mayo & frozen smoothie': 0.003199573390214638,
#  'light mayo & green tea': 0.004399413411545127,
#  'barbecue sauce & eggs': 0.0035995200639914677,
#  'pancakes & eggs': 0.021730435941874418,
#  'pancakes & cereals': 0.004666044527396347,
#  'pancakes & french fries': 0.020130649246767097,
#  'pancakes & pepper': 0.004799360085321957,
#  'pancakes & olive oil': 0.010798560191974404,
#  'pancakes & frozen vegetables': 0.013464871350486601,
#  'pancakes & energy drink': 0.0037328356219170776,
#  'pancakes & vegetables mix': 0.0035995200639914677,
#  'pancakes & almonds': 0.0030662578322890282,
#  'pancakes & french wine': 0.0041327822956939075,
#  'pancakes & whole wheat rice': 0.006932409012131715,
#  'pancakes & low fat yogurt': 0.009465404612718305,
#  'pancakes & escalope': 0.005865884548726837,
#  'pancakes & milk': 0.01653112918277563,
#  'pancakes & spaghetti': 0.025196640447940274,
#  'pancakes & turkey': 0.009598720170643914,
#  'pancakes & cottage cheese': 0.005199306759098787,
#  'pancakes & ground beef': 0.014531395813891481,
#  'pancakes & honey': 0.006665777896280496,
#  'pancakes & avocado': 0.004399413411545127,
#  'pancakes & cake': 0.011865084655379284,
#  'pancakes & frozen smoothie': 0.009065457938941474,
#  'pancakes & butter': 0.0041327822956939075,
#  'pancakes & tomato juice': 0.004932675643247567,
#  'pancakes & light cream': 0.0034662045060658577,
#  'pancakes & green tea': 0.01639781362485002,
#  'tomato sauce & milk': 0.0029329422743634183,
#  'tomato sauce & spaghetti': 0.006265831222503666,
#  'tomato sauce & ground beef': 0.005332622317024397,
#  'eggs & cereals': 0.0037328356219170776,
#  'eggs & french fries': 0.036395147313691506,
#  'eggs & pepper': 0.004666044527396347,
#  'eggs & olive oil': 0.011998400213304892,
#  'eggs & mint': 0.0029329422743634183,
#  'eggs & frozen vegetables': 0.021730435941874418,
#  'eggs & energy drink': 0.004932675643247567,
#  'eggs & bacon': 0.0029329422743634183,
#  'eggs & black tea': 0.004932675643247567,
#  'eggs & vegetables mix': 0.004799360085321957,
#  'eggs & almonds': 0.006532462338354886,
#  'eggs & french wine': 0.005999200106652446,
#  'eggs & strawberries': 0.0037328356219170776,
#  'eggs & carrots': 0.0029329422743634183,
#  'eggs & whole wheat rice': 0.010931875749900012,
#  'eggs & low fat yogurt': 0.01679776029862685,
#  'eggs & protein bar': 0.003332888948140248,
#  'eggs & escalope': 0.011065191307825623,
#  'eggs & milk': 0.03079589388081589,
#  'eggs & parmesan cheese': 0.004532728969470737,
#  'eggs & spaghetti': 0.036528462871617116,
#  'eggs & turkey': 0.01946407145713905,
#  'eggs & cottage cheese': 0.005599253432875617,
#  'eggs & meatballs': 0.004399413411545127,
#  'eggs & ground beef': 0.019997333688841486,
#  'eggs & honey': 0.005732568990801226,
#  'eggs & cider': 0.004266097853619517,
#  'eggs & avocado': 0.005599253432875617,
#  'eggs & cake': 0.019064124783362217,
#  'eggs & frozen smoothie': 0.011065191307825623,
#  'eggs & butter': 0.0061325156645780565,
#  'eggs & tomato juice': 0.005065991201173177,
#  'eggs & light cream': 0.003332888948140248,
#  'eggs & green tea': 0.025463271563791495,
#  'cereals & french fries': 0.004799360085321957,
#  'cereals & olive oil': 0.0029329422743634183,
#  'cereals & frozen vegetables': 0.004266097853619517,
#  'cereals & milk': 0.007065724570057326,
#  'cereals & spaghetti': 0.006665777896280496,
#  'cereals & ground beef': 0.004532728969470737,
#  'cereals & cake': 0.0030662578322890282,
#  'cereals & green tea': 0.006532462338354886,
#  'french fries & pepper': 0.0038661511798426876,
#  'french fries & olive oil': 0.009198773496867084,
#  'french fries & frozen vegetables': 0.019064124783362217,
#  'french fries & energy drink': 0.0061325156645780565,
#  'french fries & vegetables mix': 0.005599253432875617,
#  'french fries & almonds': 0.004399413411545127,
#  'french fries & french wine': 0.0037328356219170776,
#  'french fries & strawberries': 0.005732568990801226,
#  'french fries & whole wheat rice': 0.010531929076123183,
#  'french fries & low fat yogurt': 0.013331555792560993,
#  'french fries & protein bar': 0.0034662045060658577,
#  'french fries & escalope': 0.01639781362485002,
#  'french fries & milk': 0.023730169310758567,
#  'french fries & parmesan cheese': 0.0029329422743634183,
#  'french fries & spaghetti': 0.027596320490601255,
#  'french fries & turkey': 0.010665244634048793,
#  'french fries & cottage cheese': 0.005865884548726837,
#  'french fries & meatballs': 0.0030662578322890282,
#  'french fries & ground beef': 0.01386481802426343,
#  'french fries & honey': 0.008932142381015865,
#  'french fries & cider': 0.0029329422743634183,
#  'french fries & avocado': 0.007998933475536596,
#  'french fries & cake': 0.01786428476203173,
#  'french fries & frozen smoothie': 0.014531395813891481,
#  'french fries & butter': 0.0061325156645780565,
#  'french fries & tomato juice': 0.007065724570057326,
#  'french fries & green tea': 0.028529529396080524,
#  'pepper & olive oil': 0.003199573390214638,
#  'pepper & escalope': 0.0030662578322890282,
#  'pepper & milk': 0.005065991201173177,
#  'pepper & spaghetti': 0.009865351286495135,
#  'pepper & turkey': 0.0038661511798426876,
#  'pepper & ground beef': 0.006532462338354886,
#  'pepper & frozen smoothie': 0.0029329422743634183,
#  'pepper & green tea': 0.005199306759098787,
#  'extra dark chocolate & spaghetti': 0.0041327822956939075,
#  'olive oil & frozen vegetables': 0.011331822423676844,
#  'olive oil & almonds': 0.0029329422743634183,
#  'olive oil & french wine': 0.0034662045060658577,
#  'olive oil & whole wheat rice': 0.0034662045060658577,
#  'olive oil & low fat yogurt': 0.006799093454206106,
#  'olive oil & milk': 0.017064391414478068,
#  'olive oil & spaghetti': 0.022930275963204905,
#  'olive oil & turkey': 0.005332622317024397,
#  'olive oil & cottage cheese': 0.0034662045060658577,
#  'olive oil & ground beef': 0.014131449140114652,
#  'olive oil & honey': 0.004799360085321957,
#  'olive oil & avocado': 0.0034662045060658577,
#  'olive oil & cake': 0.006532462338354886,
#  'olive oil & frozen smoothie': 0.006932409012131715,
#  'olive oil & light cream': 0.003199573390214638,
#  'olive oil & green tea': 0.009998666844420743,
#  'mint & milk': 0.003199573390214638,
#  'mint & spaghetti': 0.003999466737768298,
#  'mint & green tea': 0.0029329422743634183,
#  'frozen vegetables & vegetables mix': 0.004399413411545127,
#  'frozen vegetables & almonds': 0.0030662578322890282,
#  'frozen vegetables & french wine': 0.003199573390214638,
#  'frozen vegetables & whole wheat rice': 0.009065457938941474,
#  'frozen vegetables & low fat yogurt': 0.010131982402346354,
#  'frozen vegetables & escalope': 0.007598986801759766,
#  'frozen vegetables & milk': 0.023596853752832957,
#  'frozen vegetables & parmesan cheese': 0.005465937874950006,
#  'frozen vegetables & spaghetti': 0.027862951606452472,
#  'frozen vegetables & turkey': 0.008798826823090255,
#  'frozen vegetables & cottage cheese': 0.0041327822956939075,
#  'frozen vegetables & meatballs': 0.0030662578322890282,
#  'frozen vegetables & ground beef': 0.01693107585655246,
#  'frozen vegetables & honey': 0.007598986801759766,
#  'frozen vegetables & avocado': 0.004666044527396347,
#  'frozen vegetables & cake': 0.010265297960271964,
#  'frozen vegetables & frozen smoothie': 0.009998666844420743,
#  'frozen vegetables & butter': 0.0038661511798426876,
#  'frozen vegetables & tomato juice': 0.004932675643247567,
#  'frozen vegetables & green tea': 0.01439808025596587,
#  'energy drink & milk': 0.003332888948140248,
#  'energy drink & spaghetti': 0.004266097853619517,
#  'energy drink & cake': 0.0035995200639914677,
#  'energy drink & green tea': 0.003999466737768298,
#  'green beans & spaghetti': 0.0034662045060658577,
#  'bacon & spaghetti': 0.003199573390214638,
#  'black tea & milk': 0.004266097853619517,
#  'black tea & spaghetti': 0.004532728969470737,
#  'black tea & green tea': 0.0029329422743634183,
#  'vegetables mix & milk': 0.004399413411545127,
#  'vegetables mix & spaghetti': 0.005599253432875617,
#  'vegetables mix & frozen smoothie': 0.003332888948140248,
#  'vegetables mix & green tea': 0.005065991201173177,
#  'magazines & green tea': 0.0029329422743634183,
#  'almonds & milk': 0.005199306759098787,
#  'almonds & spaghetti': 0.005999200106652446,
#  'almonds & ground beef': 0.0038661511798426876,
#  'almonds & cake': 0.0030662578322890282,
#  'almonds & green tea': 0.005065991201173177,
#  'french wine & milk': 0.004932675643247567,
#  'french wine & spaghetti': 0.007732302359685375,
#  'french wine & ground beef': 0.0038661511798426876,
#  'french wine & green tea': 0.0035995200639914677,
#  'blueberries & spaghetti': 0.0034662045060658577,
#  'strawberries & spaghetti': 0.0041327822956939075,
#  'strawberries & green tea': 0.0034662045060658577,
#  'carrots & milk': 0.0029329422743634183,
#  'carrots & spaghetti': 0.004666044527396347,
#  'carrots & green tea': 0.0035995200639914677,
#  'whole wheat rice & low fat yogurt': 0.006532462338354886,
#  'whole wheat rice & escalope': 0.005199306759098787,
#  'whole wheat rice & milk': 0.011865084655379284,
#  'whole wheat rice & spaghetti': 0.014131449140114652,
#  'whole wheat rice & turkey': 0.007065724570057326,
#  'whole wheat rice & ground beef': 0.008132249033462205,
#  'whole wheat rice & honey': 0.0038661511798426876,
#  'whole wheat rice & avocado': 0.0038661511798426876,
#  'whole wheat rice & cake': 0.007732302359685375,
#  'whole wheat rice & frozen smoothie': 0.005999200106652446,
#  'whole wheat rice & butter': 0.003199573390214638,
#  'whole wheat rice & green tea': 0.009065457938941474,
#  'low fat yogurt & escalope': 0.004666044527396347,
#  'low fat yogurt & milk': 0.013198240234635382,
#  'low fat yogurt & spaghetti': 0.015197973603519531,
#  'low fat yogurt & turkey': 0.005065991201173177,
#  'low fat yogurt & ground beef': 0.009598720170643914,
#  'low fat yogurt & honey': 0.003999466737768298,
#  'low fat yogurt & cake': 0.006932409012131715,
#  'low fat yogurt & frozen smoothie': 0.007332355685908546,
#  'low fat yogurt & butter': 0.004399413411545127,
#  'low fat yogurt & tomato juice': 0.0035995200639914677,
#  'low fat yogurt & green tea': 0.007598986801759766,
#  'protein bar & milk': 0.0029329422743634183,
#  'protein bar & spaghetti': 0.005065991201173177,
#  'protein bar & ground beef': 0.0035995200639914677,
#  'protein bar & green tea': 0.0029329422743634183,
#  'gums & spaghetti': 0.0030662578322890282,
#  'gums & green tea': 0.003199573390214638,
#  'escalope & milk': 0.007732302359685375,
#  'escalope & spaghetti': 0.013998133582189041,
#  'escalope & turkey': 0.004266097853619517,
#  'escalope & ground beef': 0.008265564591387815,
#  'escalope & honey': 0.0038661511798426876,
#  'escalope & cake': 0.0041327822956939075,
#  'escalope & frozen smoothie': 0.005465937874950006,
#  'escalope & green tea': 0.008932142381015865,
#  'milk & parmesan cheese': 0.0038661511798426876,
#  'milk & spaghetti': 0.03546193840821224,
#  'milk & turkey': 0.011331822423676844,
#  'milk & cottage cheese': 0.004666044527396347,
#  'milk & meatballs': 0.005465937874950006,
#  'milk & ground beef': 0.021997067057725635,
#  'milk & honey': 0.007732302359685375,
#  'milk & cider': 0.003332888948140248,
#  'milk & avocado': 0.007465671243834155,
#  'milk & cake': 0.013331555792560993,
#  'milk & frozen smoothie': 0.014264764698040262,
#  'milk & butter': 0.0061325156645780565,
#  'milk & tomato juice': 0.005732568990801226,
#  'milk & light cream': 0.003999466737768298,
#  'milk & green tea': 0.01759765364618051,
#  'parmesan cheese & spaghetti': 0.006799093454206106,
#  'parmesan cheese & ground beef': 0.0035995200639914677,
#  'parmesan cheese & cake': 0.0030662578322890282,
#  'spaghetti & nonfat milk': 0.003332888948140248,
#  'spaghetti & turkey': 0.01653112918277563,
#  'spaghetti & cottage cheese': 0.006932409012131715,
#  'spaghetti & meatballs': 0.006399146780429276,
#  'spaghetti & ground beef': 0.03919477403012932,
#  'spaghetti & honey': 0.011865084655379284,
#  'spaghetti & avocado': 0.007998933475536596,
#  'spaghetti & cake': 0.018130915877882948,
#  'spaghetti & frozen smoothie': 0.01559792027729636,
#  'spaghetti & butter': 0.006265831222503666,
#  'spaghetti & tomato juice': 0.007465671243834155,
#  'spaghetti & light cream': 0.005332622317024397,
#  'spaghetti & green tea': 0.026529796027196375,
#  'turkey & ground beef': 0.009198773496867084,
#  'turkey & honey': 0.005732568990801226,
#  'turkey & avocado': 0.0037328356219170776,
#  'turkey & cake': 0.006932409012131715,
#  'turkey & frozen smoothie': 0.0041327822956939075,
#  'turkey & butter': 0.0029329422743634183,
#  'turkey & tomato juice': 0.003199573390214638,
#  'turkey & green tea': 0.011865084655379284,
#  'cottage cheese & ground beef': 0.0030662578322890282,
#  'cottage cheese & cake': 0.004399413411545127,
#  'cottage cheese & frozen smoothie': 0.004932675643247567,
#  'cottage cheese & green tea': 0.006399146780429276,
#  'meatballs & ground beef': 0.003199573390214638,
#  'meatballs & green tea': 0.0034662045060658577,
#  'ground beef & honey': 0.006799093454206106,
#  'ground beef & avocado': 0.0037328356219170776,
#  'ground beef & cake': 0.008132249033462205,
#  'ground beef & frozen smoothie': 0.007598986801759766,
#  'ground beef & butter': 0.0038661511798426876,
#  'ground beef & tomato juice': 0.0035995200639914677,
#  'ground beef & light cream': 0.003332888948140248,
#  'ground beef & green tea': 0.014798026929742702,
#  'honey & avocado': 0.003199573390214638,
#  'honey & cake': 0.004399413411545127,
#  'honey & frozen smoothie': 0.005865884548726837,
#  'honey & green tea': 0.009332089054792695,
#  'avocado & cake': 0.004266097853619517,
#  'avocado & frozen smoothie': 0.005065991201173177,
#  'avocado & green tea': 0.006265831222503666,
#  'cake & frozen smoothie': 0.006399146780429276,
#  'cake & butter': 0.0029329422743634183,
#  'cake & tomato juice': 0.0038661511798426876,
#  'cake & green tea': 0.014131449140114652,
#  'frozen smoothie & tomato juice': 0.0037328356219170776,
#  'frozen smoothie & green tea': 0.011198506865751233,
#  'butter & green tea': 0.007332355685908546,
#  'tomato juice & green tea': 0.006265831222503666}

# %% [markdown]
# ### Visualization

# %%
eclat_itemsets_df = pd.DataFrame(list(eclat_supports.items()), columns=['Itemset', 'Support'])

# Sort by support in descending order
df_sorted = eclat_itemsets_df.sort_values(by='Support', ascending=False)
df_sorted
# Out:
#                          Itemset   Support
# 431    mineral water & spaghetti  0.059725
# 213    chocolate & mineral water  0.052660
# 405         mineral water & eggs  0.050927
# 429         mineral water & milk  0.047994
# 436  mineral water & ground beef  0.040928
# ..                           ...       ...
# 710               carrots & milk  0.002933
# 739      protein bar & green tea  0.002933
# 646          olive oil & almonds  0.002933
# 287    cooking oil & fresh bread  0.002933
# 697        magazines & green tea  0.002933
#
# [818 rows x 2 columns]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# And there we have it! Association rule algorithms like Apriori and Eclat help uncover buying patterns in transaction data. The discovered high-confidence, high-lift rules provide actionable insights for strategic product placement, bundle creation, and personalized recommendation systems for our shop owner. By implementing these rules into her sales strategy, the owner can enhance the customer shopping experience while simultaneously increasing average order value. Future work could explore combining these insights with customer segmentation data to create even more targeted upselling approaches, potentially incorporating temporal patterns to anticipate seasonal buying behaviors.
